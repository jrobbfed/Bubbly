# %%
# %matplotlib inline
from functions import *
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
cube_path = '../carma/nro_maps/nro_13co_dv0.2kms.fits'

# %%
nro_cube = fits.open(cube_path)[0].data
nro_hdr = fits.open(cube_path)[0].header
# Out:
# WARNING: VerifyWarning: Invalid value for 'BLANK' keyword in header: -1.0 The 'BLANK' keyword must be an integer.  It will be ignored in the meantime. [astropy.io.fits.hdu.image]
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]

# %%
print(nro_cube.shape)
fig, ax = plt.subplots(figsize=(8,8))
plt.imshow(nro_cube[155])
# Out:
# (340, 928, 519)

# %% [markdown]
# ---
# # Testing on One Pixel

# %%
pixel = [330, 600]
spectrum = nro_cube[:,pixel[1],pixel[0]]
plt.plot(spectrum, label="Pixel ({}, {})".format(pixel[0], pixel[1]))
plt.legend()

# %% [markdown]
# -------------
# ### Testing Noise Calculator
# from functions.noise_calculator()

# %% [markdown]
# If CONT_COR = 1, then zero the spectrum by subtracting the minimum value.

# %%
zerop = np.min(spectrum)
spectrum_zp = spectrum - zerop
plt.plot(spectrum_zp, label="Zero-point subtracted")
plt.plot(spectrum, label="Unsubtracted")
plt.legend(loc='upper left', fontsize=10)

# %%
zlen = np.size(spectrum)
ind_max = spectrum.argmax(axis=0)
print(ind_max)
ind_out = ind_max - zlen / 2
ind_aux = ind_max + zlen / 2
ind_out[np.where(ind_out < 0)] = ind_aux[np.where(ind_out < 0)]
# Out:
# 180
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-bd97e4fe36eb> in <module>()
#       4 ind_out = ind_max - zlen / 2
#       5 ind_aux = ind_max + zlen / 2
# ----> 6 ind_out[np.where(ind_out < 0)] = ind_aux[np.where(ind_out < 0)]
#
# IndexError: invalid index to scalar variable.
